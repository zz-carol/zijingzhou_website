# %% [markdown]
# # Lab 6.2
#
# Goals:
#
# * Graph two-variable functions
# * Use built-in tools to approximate integrals.
# * Use random sampling to approximate integrals.
# * Measure the running time of a program

# %% [markdown]
# Here are your libraries.

# %%
import numpy as np
import scipy.integrate as integrate
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# This code block defines five functions. You will be approximating the volume under the graph of $z=f(x,y)$.  The actual volume of each is also defined in this block.

# %%
def f1(x,y): 
  if (64-16*x**2-4*y**2)>=0:
    return np.sqrt(64-16*x**2-4*y**2)
  else:
    return 0

volume1=128/3*np.pi

def f2(x,y): #carol
  return np.sqrt(36-9*x**2-4*y**2)

volume2=24*np.pi

def f3(x,y): #asuka
  return np.sqrt(16-4*x**2-y**2)

volume3=64/3*np.pi

def f4(x,y):
  return np.sqrt(36-9*x**2-y**2)

volume4=48*np.pi

def f5(x,y):
  return np.sqrt(100-25*x**2-4*y**2)

volume5=200/3*np.pi

# %% [markdown]
# # Questions
# Write answers to these questions using code and text cells.  When you are satisfied, download and submit an .ipynb file to Gradescope.

# %% [markdown]
# ## Q1
# Create a nice graph of $z=f(x,y)$.  Your graph should have
# * A title
# * Labelled axes
# * An appropriate domain and viewing window to see the entire region below this graph

# %%
x,y=np.meshgrid(np.arange(-2,2,0.1),np.arange(-3,3,0.1))
fig = plt.figure()
ax = plt.axes(projection='3d',xlim=(-2,2), ylim=(-3,3), zlim=(0,6))
ax.set_title('The graph of f2(x,y)')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.plot_surface(x, y, f2(x,y), color="blue")
plt.show()
# Out:
# <ipython-input-2-60d7d5b047cc>:10: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(36-9*x**2-4*y**2)
# <ipython-input-35-0b7c214944ff>:8: UserWarning: Z contains NaN values. This may result in rendering artifacts.
#   ax.plot_surface(x, y, f2(x,y), color="blue")

# %% [markdown]
# ## Q2
#
# In a code cell:
# * Copy your code from the pre-lab that uses random sampling to approximate volume and plot the sample points.
# * Adjust the range of random x, y, and z values to cover your graph.
# * Adjust your `if` statement to determine which points are under your graph.  You should still be able to test this without using a square root.
# * Produce a scatter plot of your points.
# * Produce the volume approximation corresponding to your points.  Remember that the total volume of your sample space is not 4 anymore.

# %%
inPointsxValues=[]
outPointsxValues=[]
inPointsyValues=[]
outPointsyValues=[]
inPointszValues=[]
outPointszValues=[]
n=1000
for i in range(n):
  x,y,z=np.random.uniform(-2,2),np.random.uniform(-3,3),np.random.uniform(0,6)
  if z<f2(x,y):
    inPointsxValues.append(x)
    inPointsyValues.append(y)
    inPointszValues.append(z)
  else:
    outPointsxValues.append(x)
    outPointsyValues.append(y)
    outPointszValues.append(z)
x,y=np.meshgrid(np.arange(-2,2,0.1),np.arange(-3,3,0.1))
fig = plt.figure()
ax = plt.axes(projection='3d',xlim=(-2,2), ylim=(-3,3), zlim=(0,6))
ax.set_title('The graph of f2(x,y)')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.plot_surface(x, y, f2(x,y), color="blue", alpha=0.2)
ax.scatter(inPointsxValues,inPointsyValues,inPointszValues,color="b")
ax.scatter(outPointsxValues,outPointsyValues,outPointszValues,color="r")
plt.show()
# Out:
# <ipython-input-2-60d7d5b047cc>:10: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(36-9*x**2-4*y**2)
# <ipython-input-34-fb6a067b794f>:25: UserWarning: Z contains NaN values. This may result in rendering artifacts.
#   ax.plot_surface(x, y, f2(x,y), color="blue", alpha=0.2)

# %%
print(f'The volume is approximately {len(inPointsxValues)/n*144}')
print(volume2) # for comparision
# Out:
# The volume is approximately 75.888
# 75.39822368615503

# %% [markdown]
# ## Q3
#
# Copy your code from Q2 into a code cell. Then
# * Remove the graphing steps.
# * Add a line to compute the error in the approximation, using the actual volume you were given.
# * Run the cell for n=1000,10000,100000,1000000,10000000.  Record the errors and running times for each (running times appear beside the run button on the code cell).

# %% [markdown]
# Here is a table template you may use, if you want.
#
#
#
# |Number of samples|Error|Running time|
# ---|---|---
# |1000|put error here|put running time here|
# |10000|put error here|put running time here|

# %% [markdown]
# |Number of samples|Error|Running time|
# ---|---|---
# |1000|-0.9502236861550273|0s|
# |10000|0.345776313844965|0s|
# |100000|-0.08190368615503019|1s|
# |1000000|0.013424313844978997|12s|
# |10000000|0.01859391384496689|1m 58s|

# %%
inPointsxValues=[]
outPointsxValues=[]
inPointsyValues=[]
outPointsyValues=[]
inPointszValues=[]
outPointszValues=[]
n=1000
for i in range(n):
  x,y,z=np.random.uniform(-2,2),np.random.uniform(-3,3),np.random.uniform(0,6)
  if z<f2(x,y):
    inPointsxValues.append(x)
    inPointsyValues.append(y)
    inPointszValues.append(z)
  else:
    outPointsxValues.append(x)
    outPointsyValues.append(y)
    outPointszValues.append(z)
error=((len(inPointsxValues)/n*144)-volume2)
print(error)
# Out:
# -0.9502236861550273
# <ipython-input-2-60d7d5b047cc>:10: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(36-9*x**2-4*y**2)

# %%
inPointsxValues=[]
outPointsxValues=[]
inPointsyValues=[]
outPointsyValues=[]
inPointszValues=[]
outPointszValues=[]
n=10000
for i in range(n):
  x,y,z=np.random.uniform(-2,2),np.random.uniform(-3,3),np.random.uniform(0,6)
  if z<f2(x,y):
    inPointsxValues.append(x)
    inPointsyValues.append(y)
    inPointszValues.append(z)
  else:
    outPointsxValues.append(x)
    outPointsyValues.append(y)
    outPointszValues.append(z)
error=((len(inPointsxValues)/n*144)-volume2)
print(error)
# Out:
# 0.345776313844965
# <ipython-input-2-60d7d5b047cc>:10: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(36-9*x**2-4*y**2)

# %%
inPointsxValues=[]
outPointsxValues=[]
inPointsyValues=[]
outPointsyValues=[]
inPointszValues=[]
outPointszValues=[]
n=100000
for i in range(n):
  x,y,z=np.random.uniform(-2,2),np.random.uniform(-3,3),np.random.uniform(0,6)
  if z<f2(x,y):
    inPointsxValues.append(x)
    inPointsyValues.append(y)
    inPointszValues.append(z)
  else:
    outPointsxValues.append(x)
    outPointsyValues.append(y)
    outPointszValues.append(z)
error=((len(inPointsxValues)/n*144)-volume2)
print(error)
# Out:
# <ipython-input-2-60d7d5b047cc>:10: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(36-9*x**2-4*y**2)
# -0.08190368615503019

# %%
inPointsxValues=[]
outPointsxValues=[]
inPointsyValues=[]
outPointsyValues=[]
inPointszValues=[]
outPointszValues=[]
n=1000000
for i in range(n):
  x,y,z=np.random.uniform(-2,2),np.random.uniform(-3,3),np.random.uniform(0,6)
  if z<f2(x,y):
    inPointsxValues.append(x)
    inPointsyValues.append(y)
    inPointszValues.append(z)
  else:
    outPointsxValues.append(x)
    outPointsyValues.append(y)
    outPointszValues.append(z)
error=((len(inPointsxValues)/n*144)-volume2)
print(error)
# Out:
# <ipython-input-2-60d7d5b047cc>:10: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(36-9*x**2-4*y**2)
# 0.013424313844978997

# %%
inPointsxValues=[]
outPointsxValues=[]
inPointsyValues=[]
outPointsyValues=[]
inPointszValues=[]
outPointszValues=[]
n=10000000
for i in range(n):
  x,y,z=np.random.uniform(-2,2),np.random.uniform(-3,3),np.random.uniform(0,6)
  if z<f2(x,y):
    inPointsxValues.append(x)
    inPointsyValues.append(y)
    inPointszValues.append(z)
  else:
    outPointsxValues.append(x)
    outPointsyValues.append(y)
    outPointszValues.append(z)
error=((len(inPointsxValues)/n*144)-volume2)
print(error)
# Out:
# <ipython-input-2-60d7d5b047cc>:10: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(36-9*x**2-4*y**2)
# 0.01859391384496689

# %% [markdown]
# ## Q4
#
# We saw in the prelab that the `dblquad` approximation of the volume under a unit hemisphere was confident that its answer was within $1.00 \times 10^{-9}$.  Predict the following, citing evidence from your tests in Q3:
#
# * How high will `n` need to go to match this level of accuracy?
# * How long (pick an appropriate time unit) would the program take to run with that value of `n`?

# %% [markdown]
# 1. n will need to be 1 x 10^20 to match this level of accuracy, because 1 x 10^3 and 1 x 10^4 corresponds with answers within 1 x 10^-1, and 1 x 10^5 and 1 x 10^6 corresponds with answers within 1 x 10^-2.
# 2. It will take 24 hours to run with that value of n because I tried n = 100000000, it takes more than 15 minutes.

# %% [markdown]
# If you choose n random points in a box and ask how many of them are inside the region, you are computing the volume of the expected number of points, which is np (p is the volume of the region divided by the volume of the box you are picking the points from). The standard deviation is √n * √p(1-p).

# %% [markdown]
# ## Q5 (Optional)
# In a code cell
# * Define x and y bounds (numbers and functions) for the domain of your function.
# * Use `integrate.dblquad()` to compute the volume under this graph.  You can get your bounds using algebra (and perhaps by viewing your graph from Q1).
# * Using the actual value defined above, add a line of code to compute and print the actual error in the `dblquad` computation.
#
# Notice that the error is actually quite large.  `dblquad` seems to have trouble with elliptical domains.

# %% [markdown]
# ## Q6 (Optional Math)
#
# Consider the region $R$ enclosed by $y=4$ and $y=4x^2+z^2$. Its volume is: $$\iiint_R 1dV.$$
# Try using `integrate.tplquad` to evaluate this integral.  See Section 6.4 if you want to recall how we set up this integral.  `tplquad` has 7 arguments.
#
# * The first argument is the integrand (a function of x, y and z)
# * The next two arguments are the lower and upper x bounds (numbers)
# * The next two arguments are the lower and upper y bounds (functions of x)
# * The last two arguments are the lower and upper z bounds (functions of x and y)
